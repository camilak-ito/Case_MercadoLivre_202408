# %%
# !pip install ydata-profiling pandas openpyxl ipywidgets
# Out:
# ...
#   Using cached ydata_profiling-4.9.0-py2.py3-none-any.whl.metadata (20 kB)
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.2/356.2 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 13.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 7.6 MB/s eta 0:00:00
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 40.1 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=263d932b7aaf337804c444f9d38e11bbb8d7105209ae7e3b635b5c755691b0c8
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...

# %%
import pandas as pd
from ydata_profiling import ProfileReport
pd.set_option('display.max_columns', 1000, 'display.width', 1000, 'display.max_rows',1000)

# %%
df_t = pd.read_excel("Fonte_original_sem_2023.xlsx").set_index("Year")

# %%
profile = df_t.profile_report(
    title="Argentina internet usage",
    correlations={
            "auto": {"calculate": False},
            "pearson": {"calculate": True},
            "spearman": {"calculate": False},
            "kendall": {"calculate": False},
            "phi_k": {"calculate": False},
            "cramers": {"calculate": False},
        },
    # variables=None,
    samples=None,
    missing_diagrams=None,
    duplicates=None,
    interactions=None,
)

# %%
profile.to_file('data_profiling_report.html', silent=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:363: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-532c9075c6e1> in <cell line: 1>()
# ----> 1 profile.to_file('data_profiling_report.html', silent=False)
#
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py in to_file(self, output_file, silent)
#     398                 from google.colab import files  # noqa: F401
#     399
# --> 400                 files.download(output_file.absolute().as_uri())
#     401             except ModuleNotFoundError:
#     402                 import webbrowser
#
# /usr/local/lib/python3.10/dist-packages/google/colab/files.py in download(filename)
# ...
